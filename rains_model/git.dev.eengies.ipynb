# %%
# mount dev.eengies google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# clone repo rains
# %cd /content/drive/My\ Drive/DataScienTest/
#!git clone https://github.com/emericericrainsds/rains

# %%
# %cd /content/drive/My\ Drive/DataScienTest/rains/
#!git checkout dev.eengies
# !git status
# Out:
# /content/drive/My Drive/DataScienTest/rains
# Already on 'dev.eengies'
# Your branch is up to date with 'origin/dev.eengies'.
# On branch dev.eengies
# Your branch is up to date with 'origin/dev.eengies'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	git.dev.eengies.ipynb
# 	"input/docs/Pre\314\201sentation des projets MAR22CDE.pptx"
#
# nothing added to commit but untracked files present (use "git add" to track)
